# %%
# dataset disponivel em: 
# https://www.kaggle.com/datasets/robikscube/flight-delay-dataset-20182022

# %%
# carregando as bibliotecas
import os
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Criando dataframes separadamente por ano e após carregar em um único dataframe

df_flights = pd.DataFrame()

# %%
# Criando um dataframe para 2018

flights_2018 = pd.DataFrame()
for j in range(1,13):
    file = Path(f'C:/Users/Raymundo/Documentos/Estudos/UFPR-Estatistica/2_Periodo/CE329 - Aprendizagem de Maquina/Trabalho Machine Learning/Projeto04/Dataset/raw/Flights_2018_{j}.csv')
    
    import_df = pd.read_csv(file,low_memory=False,engine='c')
    flights_2018 = pd.concat([flights_2018,import_df],ignore_index=True)
    
flights_2018.head(10)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2018        1      1          23          2  2018-01-23
# 1  2018        1      1          24          3  2018-01-24
# 2  2018        1      1          25          4  2018-01-25
# 3  2018        1      1          26          5  2018-01-26
# 4  2018        1      1          27          6  2018-01-27
# 5  2018        1      1          28          7  2018-01-28
# 6  2018        1      1          29          1  2018-01-29
# 7  2018        1      1          30          2  2018-01-30
# 8  2018        1      1          31          3  2018-01-31
# 9  2018        1      1           3          3  2018-01-03
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        DL                            DL_CODESHARE
# 1                        DL                            DL_CODESHARE
# 2                        DL                            DL_CODESHARE
# ...

# %%
# Criando um dataframe para 2019

flights_2019 = pd.DataFrame()
for j in range(1,13):
    file = Path(f'C:/Users/Raymundo/Documentos/Estudos/UFPR-Estatistica/2_Periodo/CE329 - Aprendizagem de Maquina/Trabalho Machine Learning/Projeto04/Dataset/raw/Flights_2019_{j}.csv')
    
    import_df = pd.read_csv(file,low_memory=False,engine='c')
    flights_2019 = pd.concat([flights_2019,import_df],ignore_index=True)
    
flights_2019.head(10)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2019        1      1           4          5  2019-01-04
# 1  2019        1      1           4          5  2019-01-04
# 2  2019        1      1           4          5  2019-01-04
# 3  2019        1      1           4          5  2019-01-04
# 4  2019        1      1           4          5  2019-01-04
# 5  2019        1      1           4          5  2019-01-04
# 6  2019        1      1           4          5  2019-01-04
# 7  2019        1      1           4          5  2019-01-04
# 8  2019        1      1           4          5  2019-01-04
# 9  2019        1      1           4          5  2019-01-04
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        UA                            UA_CODESHARE
# 1                        UA                            UA_CODESHARE
# 2                        UA                            UA_CODESHARE
# ...

# %%
# Criando um dataframe para 2020

flights_2020 = pd.DataFrame()
for j in range(1,13):
    file = Path(f'C:/Users/Raymundo/Documentos/Estudos/UFPR-Estatistica/2_Periodo/CE329 - Aprendizagem de Maquina/Trabalho Machine Learning/Projeto04/Dataset/raw/Flights_2020_{j}.csv')
    
    import_df = pd.read_csv(file,low_memory=False,engine='c')
    flights_2020 = pd.concat([flights_2020,import_df],ignore_index=True)
    
flights_2020.head(10)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2020        1      1          17          5  2020-01-17
# 1  2020        1      1          18          6  2020-01-18
# 2  2020        1      1          19          7  2020-01-19
# 3  2020        1      1          20          1  2020-01-20
# 4  2020        1      1          21          2  2020-01-21
# 5  2020        1      1          22          3  2020-01-22
# 6  2020        1      1          23          4  2020-01-23
# 7  2020        1      1          24          5  2020-01-24
# 8  2020        1      1          25          6  2020-01-25
# 9  2020        1      1          26          7  2020-01-26
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        B6                                      B6
# 1                        B6                                      B6
# 2                        B6                                      B6
# ...

# %%
# Criando um dataframe para 2021

flights_2021 = pd.DataFrame()
for j in range(1,13):
    file = Path(f'C:/Users/Raymundo/Documentos/Estudos/UFPR-Estatistica/2_Periodo/CE329 - Aprendizagem de Maquina/Trabalho Machine Learning/Projeto04/Dataset/raw/Flights_2021_{j}.csv')
    
    import_df = pd.read_csv(file,low_memory=False,engine='c')
    flights_2021 = pd.concat([flights_2021,import_df],ignore_index=True)
    
flights_2021.head(10)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       5     file = Path(f'C:/Users/Raymundo/Documentos/Estudos/UFPR-Estatistica/2_Periodo/CE329 - Aprendizagem de Maquina/Trabalho Machine Learning/Projeto04/Dataset/raw/Flights_2021_{j}.csv')
#       7     import_df = pd.read_csv(file,low_memory=False,engine='c')
# ----> 8     flights_2021 = pd.concat([flights_2021,import_df],ignore_index=True)
#      10 flights_2021.head(10)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
# Criando um dataframe para 2022

flights_2022 = pd.DataFrame()
for j in range(1,13):
    file = Path(f'C:/Users/Raymundo/Documentos/Estudos/UFPR-Estatistica/2_Periodo/CE329 - Aprendizagem de Maquina/Trabalho Machine Learning/Projeto04/Dataset/raw/Flights_2022_{j}.csv')
    
    import_df = pd.read_csv(file,low_memory=False,engine='c')
    flights_2022 = pd.concat([flights_2022,import_df],ignore_index=True)
    
flights_2022.head(10)
