# %%
# dataset disponivel em: 
# https://www.kaggle.com/datasets/dermisfit/fraud-transactions-dataset

# %%
# carregando as bibliotecas
import pandas as pd

# %%
## Carregando os dados
caminho_pasta = 'C:\\Users\\Raymundo\\Documentos\\Estudos\\UFPR-Estatistica\\2_Periodo\\CE329 - Aprendizagem de Maquina\\Trabalho Machine Learning\\Projeto05\\'

df_train = pd.read_csv(caminho_pasta + 'dataset\\fraudTrain.csv')
df_test = pd.read_csv(caminho_pasta + 'dataset\\fraudTest.csv')

# %%
## Juntando os 2 arquivos em um único dataset

df_data= pd.concat([df_test,df_train]) 
df_data
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2020-06-21 12:14:25     2291163933867244
# 1                 1   2020-06-21 12:14:33     3573030041201292
# 2                 2   2020-06-21 12:14:53     3598215285024754
# 3                 3   2020-06-21 12:15:15     3591919803438423
# 4                 4   2020-06-21 12:15:17     3526826139003047
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                      merchant        category     amt  \
# 0                       fraud_Kirlin and Sons   personal_care    2.86
# ...
